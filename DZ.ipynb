# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Скачиваем датасет.
# Снимаем оганичение на воспроизводимое количество колонок, для визуализации всех парамметров.
# Просматриваем вид датасета.

# %%
data = pd.read_csv('./AB_NYC_2019.csv', sep=',')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# Удаляем неинформативные параметры. Просмотриваем базовые статистики датасета.

# %%
list = ['id', 'name', 'host_id', 'host_name', 'last_review']
data = data.drop(list,axis = 1 )
data.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0                NaN
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               38843 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# Видем, что пустые данные есть только в столбце reviews_per_month

# %%
data.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# std        0.054530      0.046157    240.154170       20.510550
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# std            44.550582           1.680442                       32.952519
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.190000                        1.000000
# 50%             5.000000           0.720000                        1.000000
# 75%            24.000000           2.020000                        2.000000
# max           629.000000          58.500000                      327.000000
#
#        availability_365
# count      48895.000000
# mean         112.781327
# std          131.622289
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          227.000000
# max          365.000000

# %% [markdown]
# Оценим количество уникальных значений

# %%
data[['neighbourhood_group','neighbourhood','room_type','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']].nunique()
# Out:
# neighbourhood_group                 5
# neighbourhood                     221
# room_type                           3
# minimum_nights                    109
# number_of_reviews                 394
# reviews_per_month                 937
# calculated_host_listings_count     47
# availability_365                  366
# dtype: int64

# %% [markdown]
# Заполняем недостающие значения в колонке reviews_per_month. Запонить можно средним значением или использовать KNNImputer. Попробовал оба варианта, результат почти одинаков.

# %%
data['reviews_per_month'] = data['reviews_per_month'].fillna(data['reviews_per_month'].mean())

# %%
#from sklearn.impute import KNNImputer
#knn_imputer = KNNImputer(n_neighbors=2)
#data[['reviews_per_month']] = knn_imputer.fit_transform(data[['reviews_per_month']])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               48895 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 4.1+ MB

# %%
data.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# std        0.054530      0.046157    240.154170       20.510550
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# std            44.550582           1.497775                       32.952519
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.280000                        1.000000
# 50%             5.000000           1.220000                        1.000000
# 75%            24.000000           1.580000                        2.000000
# max           629.000000          58.500000                      327.000000
#
#        availability_365
# count      48895.000000
# mean         112.781327
# std          131.622289
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          227.000000
# max          365.000000

# %% [markdown]
# Для построения матрици корреляции закодируем котегориальные признаки способом OrdinalEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder 
data_enc = data.copy()
enc = OrdinalEncoder()
data_enc[['neighbourhood','neighbourhood_group','room_type']]= enc.fit_transform(data_enc[['neighbourhood','neighbourhood_group','room_type']])
data_enc.head()
# Out:
#    neighbourhood_group  neighbourhood  latitude  longitude  room_type  price  \
# 0                  1.0          108.0  40.64749  -73.97237        1.0    149
# 1                  2.0          127.0  40.75362  -73.98377        0.0    225
# 2                  2.0           94.0  40.80902  -73.94190        1.0    150
# 3                  1.0           41.0  40.68514  -73.95976        0.0     89
# 4                  2.0           61.0  40.79851  -73.94399        0.0     80
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9           0.210000
# 1               1                 45           0.380000
# 2               3                  0           1.373221
# 3               1                270           4.640000
# 4              10                  9           0.100000
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
sns.pairplot (data_enc)

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data_enc.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Вывод: Учитывая данный датасет, а также полученные графики и матрицу корреляции, можно сделать вывод что корреляция в данных отсутствует

# %% [markdown]
# Находим аномалии в данных.
# Построим графики зависимости цены от различных парамметров.

# %%
# Просто вывел чтоб не листать
data.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9           0.210000
# 1    225               1                 45           0.380000
# 2    150               3                  0           1.373221
# 3     89               1                270           4.640000
# 4     80              10                  9           0.100000
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
# Set the style for the plots
sns.set_style('whitegrid')
edgecolor = 'black'

# Function to plot scatter plot between a feature and the Price 
def scatter_plot(data,a):
    # Create a new figure for each scatter plot
    plt.figure(figsize=(20, 5))
    plt.scatter(x=data[a], y=data['price'], edgecolor=edgecolor)
    plt.ylabel('Price', fontsize=12)
    plt.xlabel(a, fontsize=12)
    plt.suptitle("Scatter Plot of " + a + " and Price", fontsize=14)
    plt.show()

# %%
features = ['neighbourhood_group','neighbourhood','room_type','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
#features = ['neighbourhood_group','neighbourhood','room_type']
for feature in features:
    scatter_plot(data, feature)

# %%
from sklearn.preprocessing import OrdinalEncoder
from category_encoders import CountEncoder
from category_encoders import OneHotEncoder

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import cross_val_score
from sklearn.metrics import *

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

# %%
# Функция оценки по R2, MAE, RSME по кросс-валидации
def evaluate_encoding2(data,model,scaler,enc,cols):
  print(model,scaler,enc,cols)
  data_enc = data.copy()
  if enc == 'OneHotEncoder':
    enc = OneHotEncoder()
    #data_enc = data_enc.drop(cols, axis = 1).join(enc.fit_transform(data_enc[[cols]], axis = 0))
    data_enc = data_enc.drop(cols, axis = 1).join(enc.fit_transform(data_enc[cols], axis = 0))
  else:
    if enc == 'OrdinalEncoder': enc = OrdinalEncoder()
    elif enc == 'CountEncoder': enc = CountEncoder()
    data_enc[cols]= enc.fit_transform(data_enc[cols])
  if scaler == 'RobustScaler': scaler = RobustScaler()
  elif scaler == 'StandardScaler': scaler = StandardScaler() 
  elif scaler == 'MinMaxScaler': scaler = MinMaxScaler()
  scaled_data = scaler.fit_transform(data_enc.drop('price', axis = 1))
  if model == 'LinearRegression': model = LinearRegression()
  elif model == 'RidgeCV': model = RidgeCV()
  elif model == 'LassoCV': model = LassoCV()
  elif model == 'ElasticNetCV': model = ElasticNetCV()
  model_res_r2 = np.mean(cross_val_score(model, scaled_data, y = data_enc.price, cv = 5, scoring = 'r2'))
  model_res_mae = np.mean(cross_val_score(model, scaled_data, y = data_enc.price, cv = 5, scoring = 'neg_mean_absolute_error'))
  model_res_rmse = np.mean(cross_val_score(model, scaled_data, y = data_enc.price, cv = 5, scoring = 'neg_root_mean_squared_error'))
  return [round(model_res_r2,4), round(model_res_mae,4), round(model_res_rmse,4)]

# %% [markdown]
# Выполним предсказание для данных без корректировки на выбросы и аномалии, для различных моделей, кодировок и стандартизации.

# %%
#Полный анализ по списку моделей, кодеровок и стандартизации
results = {}
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler_list = ['StandardScaler','RobustScaler', 'MinMaxScaler']
enc_list = ['OrdinalEncoder', 'CountEncoder', 'OneHotEncoder']
model_list = ['LinearRegression', 'RidgeCV', 'LassoCV', 'ElasticNetCV']

for scaler in scaler_list:
    for enc in enc_list:
        for model in model_list:
            results[model + ' & ' + enc + ' & ' + scaler] = evaluate_encoding2(data, model, scaler,enc,cols)
# Out:
# LinearRegression StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\linear_model\_base.py", line 751, in fit
#     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\scipy\linalg\_basic.py", line 1221, in lstsq
#     raise LinAlgError("SVD did not converge in Linear Least Squares")
# numpy.linalg.LinAlgError: SVD did not converge in Linear Least Squares
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\linear_model\_base.py", line 751, in fit
#     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\scipy\linalg\_basic.py", line 1221, in lstsq
#     raise LinAlgError("SVD did not converge in Linear Least Squares")
# numpy.linalg.LinAlgError: SVD did not converge in Linear Least Squares
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\sklearn\linear_model\_base.py", line 751, in fit
#     self.coef_, _, self.rank_, self.singular_ = linalg.lstsq(X, y)
#   File "d:\OTUS\Brand_public\.venv\lib\site-packages\scipy\linalg\_basic.py", line 1221, in lstsq
#     raise LinAlgError("SVD did not converge in Linear Least Squares")
# numpy.linalg.LinAlgError: SVD did not converge in Linear Least Squares
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']

# %%
pd.DataFrame(results, index = ['R2', 'MAE', 'RMSE'])
# Out:
#       LinearRegression & OrdinalEncoder & RobustScaler  \
# R2                                              0.0872
# MAE                                           -75.5771
# RMSE                                         -227.8413
#
#       RidgeCV & OrdinalEncoder & RobustScaler  \
# R2                                     0.0872
# MAE                                  -75.5703
# RMSE                                -227.8411
#
#       LassoCV & OrdinalEncoder & RobustScaler  \
# R2                                     0.0870
# MAE                                  -75.0169
# RMSE                                -227.8756
#
#       ElasticNetCV & OrdinalEncoder & RobustScaler  \
# R2                                          0.0633
# MAE                                       -78.7629
# RMSE                                     -230.7790
#
#       LinearRegression & CountEncoder & RobustScaler  \
# R2                                            0.0560
# MAE                                         -84.0845
# RMSE                                       -231.6672
#
#       RidgeCV & CountEncoder & RobustScaler  \
# R2                                   0.0560
# MAE                                -84.0820
# RMSE                              -231.6671
#
#       LassoCV & CountEncoder & RobustScaler  \
# R2                                   0.0558
# MAE                                -83.6893
# RMSE                              -231.7050
#
#       ElasticNetCV & CountEncoder & RobustScaler  \
# R2                                        0.0484
# MAE                                     -83.4800
# RMSE                                   -232.5781
#
#       LinearRegression & OneHotEncoder & RobustScaler  \
# R2                                      -1.914761e+12
# MAE                                     -4.128739e+06
# RMSE                                    -2.471703e+08
#
#       RidgeCV & OneHotEncoder & RobustScaler  \
# R2                                    0.1087
# MAE                                 -72.1359
# RMSE                               -225.1872
#
#       LassoCV & OneHotEncoder & RobustScaler  \
# R2                                    0.1035
# MAE                                 -72.3502
# RMSE                               -225.8220
#
#       ElasticNetCV & OneHotEncoder & RobustScaler  \
# R2                                         0.0745
# MAE                                      -76.2486
# RMSE                                    -229.4150
#
#       LinearRegression & OrdinalEncoder & MinMaxScaler  \
# R2                                              0.0872
# MAE                                           -75.5771
# RMSE                                         -227.8413
#
#       RidgeCV & OrdinalEncoder & MinMaxScaler  \
# R2                                     0.0877
# MAE                                  -75.3662
# RMSE                                -227.7801
#
#       LassoCV & OrdinalEncoder & MinMaxScaler  \
# R2                                     0.0874
# MAE                                  -74.7137
# RMSE                                -227.8267
#
#       ElasticNetCV & OrdinalEncoder & MinMaxScaler  \
# R2                                          0.0778
# MAE                                       -75.0695
# RMSE                                     -229.0375
#
#       LinearRegression & CountEncoder & MinMaxScaler  \
# R2                                            0.0560
# MAE                                         -84.0845
# RMSE                                       -231.6672
#
#       RidgeCV & CountEncoder & MinMaxScaler  \
# R2                                   0.0561
# MAE                                -84.0374
# RMSE                              -231.6557
#
#       LassoCV & CountEncoder & MinMaxScaler  \
# R2                                   0.0562
# MAE                                -83.4915
# RMSE                              -231.6545
#
#       ElasticNetCV & CountEncoder & MinMaxScaler  \
# R2                                        0.0515
# MAE                                     -83.0572
# RMSE                                   -232.2279
#
#       LinearRegression & OneHotEncoder & MinMaxScaler  \
# R2                                                NaN
# MAE                                               NaN
# RMSE                                              NaN
#
#       RidgeCV & OneHotEncoder & MinMaxScaler  \
# R2                                    0.1090
# MAE                                 -71.7385
# RMSE                               -225.1404
#
#       LassoCV & OneHotEncoder & MinMaxScaler  \
# R2                                    0.1084
# MAE                                 -71.2134
# RMSE                               -225.2226
#
#       ElasticNetCV & OneHotEncoder & MinMaxScaler
# R2                                         0.0974
# MAE                                      -71.0787
# RMSE                                    -226.6027

# %% [markdown]
# Будем выполнять модификацию данных и оценивать влияние на качество предсказания с использованием RidgeCV & OneHotEncoder & MinMaxScaler, как имеющих на данный момент самое качественное предсказание. (R2 = 0.1090, MAE = -71.7385, RMSE = -225.1404)

# %%
data_replace = data.copy()

# %%
# Удаляем строки с нулевым значение цены
data_replace = data_replace.drop(index = data_replace[data_replace['price'] == 0].index)

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.109, -71.7385, -225.1404]

# %% [markdown]
# Удаление строчек с нулевым значением никак не повлияло.

# %%
# Заменяем значение цены большей значения 95% ного квантеля на значение 95% ного квантеля для каждого 'neighbourhood'
for a in data_replace.neighbourhood.unique():
    quartile_95 = data_replace.price[data_replace['neighbourhood'] == a].quantile(0.95)
    data_replace.loc[((data_replace['price'] > quartile_95) & (data_replace['neighbourhood'] == a)), 'price'] = quartile_95

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.4361, -48.6546, -75.886]

# %% [markdown]
# Замена выбросов вверх на значение 95%-ного квантеля значительно повлияло на качество предсказания.

# %%
# Заменяем значение цены меньшей значения 5% ного квантеля на значение 5% ного квантеля для каждого 'neighbourhood'
for a in data_replace.neighbourhood.unique():
    quartile_05 = data_replace.price[data_replace['neighbourhood'] == a].quantile(0.05)
    data_replace.loc[((data_replace['price'] < quartile_05) & (data_replace['neighbourhood'] == a)), 'price'] = quartile_05

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.4372, -48.3412, -75.5388]

# %% [markdown]
# Замена выбросов вниз на значение 5% ного квантеля не значительно улучшило предсказание.

# %%
# Заменяем значение 'minimum_nights' на 365 если оно больше
data_replace.loc[(data_replace['minimum_nights'] > 365), 'minimum_nights'] = 365

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.4381, -48.147, -75.4721]

# %% [markdown]
# Замена значения 'minimum_nights' на 365 если оно больше практически не повлияло на качество предсказания.

# %%
# Заменяем значение reviews_per_month на 20 если оно больше
data_replace.loc[(data_replace['reviews_per_month'] > 20), 'reviews_per_month'] = 20

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)

# %% [markdown]
# Замена значений reviews_per_month на 20 если оно больше практичеки не повлияло на качество предсказания.

# %%
# Заменяем значение number_of_reviews на 500 если оно больше
data_replace.loc[(data_replace['number_of_reviews'] > 500), 'number_of_reviews'] = 500

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'MinMaxScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.4379, -48.2183, -75.4859]

# %% [markdown]
# Заменяем значение number_of_reviews на 500 если оно больше практичеки не повлияло на качество предсказания.

# %% [markdown]
# Вывод: значительное улучшение дало только удаление выбросов по цене, удаление выбросов по другим парамметрам практически не повлияло на предсказанеие.

# %%
data_replace.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48884.000000  48884.000000  48884.000000    48884.000000
# mean      40.728953    -73.952176    137.505194        6.942885
# std        0.054532      0.046159    101.466801       17.531526
# min       40.499790    -74.244420     20.000000        1.000000
# 25%       40.690100    -73.983080     70.000000        1.000000
# 50%       40.723080    -73.955685    106.000000        3.000000
# 75%       40.763120    -73.936290    175.000000        5.000000
# max       40.913060    -73.712990   1650.000000      365.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.259799           1.372178                        7.144628
# std            44.407853           1.474913                       32.956185
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.280000                        1.000000
# 50%             5.000000           1.220000                        1.000000
# 75%            24.000000           1.580000                        2.000000
# max           500.000000          20.000000                      327.000000
#
#        availability_365
# count      48884.000000
# mean         112.779498
# std          131.627271
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          227.000000
# max          365.000000

# %%
#Полный анализ по списку моделей, кодеровок и стандартизации
results = {}
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler_list = ['StandardScaler','RobustScaler', 'MinMaxScaler']
enc_list = ['OrdinalEncoder', 'CountEncoder', 'OneHotEncoder']
model_list = ['LinearRegression', 'RidgeCV', 'LassoCV', 'ElasticNetCV']

for scaler in scaler_list:
    for enc in enc_list:
        for model in model_list:
            results[model + ' & ' + enc + ' & ' + scaler] = evaluate_encoding2(data_replace, model, scaler,enc,cols)
# Out:
# LinearRegression StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV StandardScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler OrdinalEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler CountEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LinearRegression MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# RidgeCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# LassoCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# ElasticNetCV MinMaxScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']

# %%
pd.DataFrame(results, index = ['R2', 'MAE', 'RMSE'])
# Out:
#       LinearRegression & OrdinalEncoder & StandardScaler  \
# R2                                               0.3278
# MAE                                            -52.8590
# RMSE                                           -82.6185
#
#       RidgeCV & OrdinalEncoder & StandardScaler  \
# R2                                       0.3278
# MAE                                    -52.8575
# RMSE                                   -82.6179
#
#       LassoCV & OrdinalEncoder & StandardScaler  \
# R2                                       0.3284
# MAE                                    -52.6939
# RMSE                                   -82.5801
#
#       ElasticNetCV & OrdinalEncoder & StandardScaler  \
# R2                                            0.3288
# MAE                                         -52.6422
# RMSE                                        -82.5682
#
#       LinearRegression & CountEncoder & StandardScaler  \
# R2                                              0.2032
# MAE                                           -62.0164
# RMSE                                          -89.9785
#
#       RidgeCV & CountEncoder & StandardScaler  \
# R2                                     0.2032
# MAE                                  -62.0152
# RMSE                                 -89.9777
#
#       LassoCV & CountEncoder & StandardScaler  \
# R2                                     0.2036
# MAE                                  -62.0630
# RMSE                                 -89.9559
#
#       ElasticNetCV & CountEncoder & StandardScaler  \
# R2                                          0.2042
# MAE                                       -61.8977
# RMSE                                      -89.9192
#
#       LinearRegression & OneHotEncoder & StandardScaler  \
# R2                                        -1.644249e+25
# MAE                                       -3.578401e+12
# RMSE                                      -2.495304e+14
#
#       RidgeCV & OneHotEncoder & StandardScaler  \
# R2                                      0.4365
# MAE                                   -48.3937
# RMSE                                  -75.5757
#
#       LassoCV & OneHotEncoder & StandardScaler  \
# R2                                      0.4356
# MAE                                   -48.1172
# RMSE                                  -75.6566
#
#       ElasticNetCV & OneHotEncoder & StandardScaler  \
# R2                                           0.4365
# MAE                                        -48.0588
# RMSE                                       -75.6099
#
#       LinearRegression & OrdinalEncoder & RobustScaler  \
# R2                                              0.3278
# MAE                                           -52.8590
# RMSE                                          -82.6185
#
#       RidgeCV & OrdinalEncoder & RobustScaler  \
# R2                                     0.3278
# MAE                                  -52.8574
# RMSE                                 -82.6185
#
#       LassoCV & OrdinalEncoder & RobustScaler  \
# R2                                     0.3280
# MAE                                  -52.7123
# RMSE                                 -82.6155
#
#       ElasticNetCV & OrdinalEncoder & RobustScaler  \
# R2                                          0.2282
# MAE                                       -58.7450
# RMSE                                      -88.5275
#
#       LinearRegression & CountEncoder & RobustScaler  \
# R2                                            0.2032
# MAE                                         -62.0164
# RMSE                                        -89.9785
#
#       RidgeCV & CountEncoder & RobustScaler  \
# R2                                   0.2032
# MAE                                -62.0159
# RMSE                               -89.9785
#
#       LassoCV & CountEncoder & RobustScaler  \
# R2                                   0.2028
# MAE                                -61.9487
# RMSE                               -90.0108
#
#       ElasticNetCV & CountEncoder & RobustScaler  \
# R2                                        0.1767
# MAE                                     -62.5814
# RMSE                                    -91.4627
#
#       LinearRegression & OneHotEncoder & RobustScaler  \
# R2                                      -2.027038e+14
# MAE                                     -1.974038e+07
# RMSE                                    -1.127215e+09
#
#       RidgeCV & OneHotEncoder & RobustScaler  \
# R2                                    0.4399
# MAE                                 -48.2246
# RMSE                                -75.3593
#
#       LassoCV & OneHotEncoder & RobustScaler  \
# R2                                    0.3957
# MAE                                 -49.6674
# RMSE                                -78.2098
#
#       ElasticNetCV & OneHotEncoder & RobustScaler  \
# R2                                         0.2753
# MAE                                      -56.0299
# RMSE                                     -85.7771
#
#       LinearRegression & OrdinalEncoder & MinMaxScaler  \
# R2                                              0.3278
# MAE                                           -52.8590
# RMSE                                          -82.6185
#
#       RidgeCV & OrdinalEncoder & MinMaxScaler  \
# R2                                     0.3279
# MAE                                  -52.8425
# RMSE                                 -82.6108
#
#       LassoCV & OrdinalEncoder & MinMaxScaler  \
# R2                                     0.3286
# MAE                                  -52.6848
# RMSE                                 -82.5655
#
#       ElasticNetCV & OrdinalEncoder & MinMaxScaler  \
# R2                                          0.2986
# MAE                                       -53.7818
# RMSE                                      -84.4354
#
#       LinearRegression & CountEncoder & MinMaxScaler  \
# R2                                            0.2032
# MAE                                         -62.0164
# RMSE                                        -89.9785
#
#       RidgeCV & CountEncoder & MinMaxScaler  \
# R2                                   0.2033
# MAE                                -62.0035
# RMSE                               -89.9691
#
#       LassoCV & CountEncoder & MinMaxScaler  \
# R2                                   0.2037
# MAE                                -62.0529
# RMSE                               -89.9485
#
#       ElasticNetCV & CountEncoder & MinMaxScaler  \
# R2                                        0.1922
# MAE                                     -61.8719
# RMSE                                    -90.5789
#
#       LinearRegression & OneHotEncoder & MinMaxScaler  \
# R2                                      -8.502731e+20
# MAE                                     -2.327289e+10
# RMSE                                    -1.517902e+12
#
#       RidgeCV & OneHotEncoder & MinMaxScaler  \
# R2                                    0.4379
# MAE                                 -48.2183
# RMSE                                -75.4859
#
#       LassoCV & OneHotEncoder & MinMaxScaler  \
# R2                                    0.4363
# MAE                                 -48.1687
# RMSE                                -75.6026
#
#       ElasticNetCV & OneHotEncoder & MinMaxScaler
# R2                                         0.3901
# MAE                                      -49.3123
# RMSE                                     -78.6652

# %% [markdown]
# По итогам лучшее показатели показала связка RidgeCV & OneHotEncoder & RobustScaler (R2 = 0.4399, MAE = -48.2246, RMSE = -75.3593)

# %% [markdown]
# Добавим дополнительный столбец Евклидово расстояние до Эмпайр-стейт-билдинг в центре Манхеттена (40.74848 -73.98567)

# %%
data_new = data_replace.copy()
data_new['distance_to_ESB']= np.sqrt((data_new['latitude'] - 40.74848)**2 + (data_new['longitude'] - (-73.98567))**2)
data_new.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48884.000000  48884.000000  48884.000000    48884.000000
# mean      40.728953    -73.952176    137.505194        6.942885
# std        0.054532      0.046159    101.466801       17.531526
# min       40.499790    -74.244420     20.000000        1.000000
# 25%       40.690100    -73.983080     70.000000        1.000000
# 50%       40.723080    -73.955685    106.000000        3.000000
# 75%       40.763120    -73.936290    175.000000        5.000000
# max       40.913060    -73.712990   1650.000000      365.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48884.000000       48884.000000                    48884.000000
# mean           23.259799           1.372178                        7.144628
# std            44.407853           1.474913                       32.956185
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.280000                        1.000000
# 50%             5.000000           1.220000                        1.000000
# 75%            24.000000           1.580000                        2.000000
# max           500.000000          20.000000                      327.000000
#
#        availability_365  distance_to_ESB
# count      48884.000000     48884.000000
# mean         112.779498         0.067559
# std          131.627271         0.045202
# min            0.000000         0.000257
# 25%            0.000000         0.033438
# 50%           45.000000         0.063512
# 75%          227.000000         0.087053
# max          365.000000         0.356312

# %%
#Быстрый анализ по одной модели
cols = ['neighbourhood_group','neighbourhood','room_type']
scaler = 'RobustScaler'
enc = 'OneHotEncoder'
model = 'RidgeCV'
evaluate_encoding2(data_new, model, scaler,enc,cols)
# Out:
# RidgeCV RobustScaler OneHotEncoder ['neighbourhood_group', 'neighbourhood', 'room_type']
# [0.438, -48.217, -75.4754]

# %% [markdown]
# В данном случае добавление дополнительного признака практически не повлияло на результат

# %% [markdown]
# Выполним предссказание на основе train и test выборки для сочетания RidgeCV & OneHotEncoder & RobustScaler

# %%
from sklearn.model_selection import train_test_split

# %%
data_enc = data_replace.copy()
cols = ['neighbourhood_group','neighbourhood','room_type']
enc = OneHotEncoder()
data_enc = data_enc.drop(cols, axis = 1).join(enc.fit_transform(data_enc[cols], axis = 0))
y = data_enc['price']
x = data_enc.drop(['price'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((34218, 236), (14666, 236), (34218,), (14666,))

# %%
scaler = RobustScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#model = LGBMRegressor().fit(x_train,y_train)
model = RidgeCV().fit(x_train,y_train)
y_pred = model.predict(x_test)
R2 = r2_score (y_test, y_pred)
MAE = mean_absolute_error (y_test, y_pred)
#RMSE = root_mean_squared_error (y_test, y_pred)
print (R2,MAE)
# Out:
# 0.4493392502016854 47.31279747284613

# %% [markdown]
# Попробуем сделать предсказание на основе ансамблирования моделей (RandomForestRegressor, LGBMRegressor).

# %%
#from catboost import CatBoostRegressor # виснет 
#from xgboost import XGBRegressor
from lightgbm import LGBMRegressor # Новее и чуть лучше чем xgboost
from sklearn.ensemble import RandomForestRegressor

# %%
data_enc = data_replace.copy()
cols = ['neighbourhood_group','neighbourhood','room_type']
enc = OneHotEncoder()
data_enc = data_enc.drop(cols, axis = 1).join(enc.fit_transform(data_enc[cols], axis = 0))
y = data_enc['price']
x = data_enc.drop(['price'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((34218, 236), (14666, 236), (34218,), (14666,))

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#model = LGBMRegressor().fit(x_train,y_train)
model = RandomForestRegressor().fit(x_train,y_train)
y_pred = model.predict(x_test)
R2 = r2_score (y_test, y_pred)
MAE = mean_absolute_error (y_test, y_pred)
#RMSE = root_mean_squared_error (y_test, y_pred)
print (R2,MAE)
# Out:
# 0.5369515273078609 42.002472850470475

# %%
model = LGBMRegressor().fit(x_train,y_train)
#model = RandomForestRegressor().fit(x_train,y_train)
y_pred = model.predict(x_test)
R2 = r2_score (y_test, y_pred)
MAE = mean_absolute_error (y_test, y_pred)
#RMSE = root_mean_squared_error (y_test, y_pred)
print (R2,MAE)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012724 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1614
# [LightGBM] [Info] Number of data points in the train set: 34218, number of used features: 133
# [LightGBM] [Info] Start training from score 137.870774
# 0.5418485094379725 42.17682895000299

# %% [markdown]
# Выполним предсказание с использованием расстояния до Эмпайр-стейт-билдинг

# %%
data_enc = data_new.copy()
cols = ['neighbourhood_group','neighbourhood','room_type']
enc = OneHotEncoder()
data_enc = data_enc.drop(cols, axis = 1).join(enc.fit_transform(data_enc[cols], axis = 0))
y = data_enc['price']
x = data_enc.drop(['price'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((34218, 237), (14666, 237), (34218,), (14666,))

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#model = LGBMRegressor().fit(x_train,y_train)
model = RandomForestRegressor().fit(x_train,y_train)
y_pred = model.predict(x_test)
R2 = r2_score (y_test, y_pred)
MAE = mean_absolute_error (y_test, y_pred)
#RMSE = root_mean_squared_error (y_test, y_pred)
print (R2,MAE)
# Out:
# 0.541143573468053 42.03708083037865

# %%
model = LGBMRegressor().fit(x_train,y_train)
#model = RandomForestRegressor().fit(x_train,y_train)
y_pred = model.predict(x_test)
R2 = r2_score (y_test, y_pred)
MAE = mean_absolute_error (y_test, y_pred)
#RMSE = root_mean_squared_error (y_test, y_pred)
print (R2,MAE)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008410 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1869
# [LightGBM] [Info] Number of data points in the train set: 34218, number of used features: 134
# [LightGBM] [Info] Start training from score 137.870774
# 0.5450303123908524 42.16056702589496

# %% [markdown]
# Выводы:
# - Кодировка категориальных признаков с помощью OneHotEncoder показало значительное увеличение качества предсказания по сравнению с другими способами кодировки.
# - Модели с ассамблированием показывают лучшие результаты предсказания
# - Для моделей с ассамблированием, ввод дополнительных парамметров улучшает качество предсказания (если ввести больше дополнительных парраметров, можно значительно улучшить качество предсказания.)
